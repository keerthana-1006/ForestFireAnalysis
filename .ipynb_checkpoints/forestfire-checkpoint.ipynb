# %% [markdown]
# ### Data Cleaning

# %%
# Data Cleaning

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('C:\\Users\\ACER\\OneDrive\\Documents\\New_fire.csv')

# Display the first few rows of the dataset
data.head(10)
# Out:
#    x  y month  day  ffmc    dmc     dc   isi  temp  rh  wind  rain  area
# 0  7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.0
# 5  8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.0
# 6  8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.0
# 7  8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.0
# 8  8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.0
# 9  7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.0

# %%
print (data.shape)
# Out:
# (517, 13)

# %%
# Display basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       517 non-null    int64
#  1   y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   ffmc    517 non-null    float64
#  5   dmc     517 non-null    float64
#  6   dc      517 non-null    float64
#  7   isi     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   rh      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
# Check for missing values
data.isnull().sum()
# Out:
# x        0
# y        0
# month    0
# day      0
# ffmc     0
# dmc      0
# dc       0
# isi      0
# temp     0
# rh       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
# Summary statistics
data.describe()
# Out:
#                 x           y        ffmc         dmc          dc         isi  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          rh        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# std      5.806625   16.317469    1.791653    0.295959    63.655818
# min      2.200000   15.000000    0.400000    0.000000     0.000000
# 25%     15.500000   33.000000    2.700000    0.000000     0.000000
# 50%     19.300000   42.000000    4.000000    0.000000     0.520000
# 75%     22.800000   53.000000    4.900000    0.000000     6.570000
# max     33.300000  100.000000    9.400000    6.400000  1090.840000

# %%
# Outlier Analysis

# Visualizing outliers using box plots for each numeric variable
plt.figure(figsize=(15, 10))
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns

for i, col in enumerate(numeric_columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(y=data[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# Detecting outliers using the IQR method
outliers = pd.DataFrame()

for col in numeric_columns:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers[col] = ((data[col] < lower_bound) | (data[col] > upper_bound))

# Display the count of outliers in each column
outliers_sum = outliers.sum()
print(outliers_sum)
# Out:
# x        0
# y       51
# ffmc    53
# dmc     17
# dc       8
# isi     23
# temp     2
# rh      12
# wind    13
# rain     8
# area    63
# dtype: int64

# %%
# Capping outliers at the 1st and 99th percentiles

# Copy the original data to avoid modifying it directly
data_capped = data.copy()

# Loop through each numeric column to cap outliers
for col in numeric_columns:
    lower_cap = data_capped[col].quantile(0.01)  # 1st percentile
    upper_cap = data_capped[col].quantile(0.99)  # 99th percentile
    # Cap the values outside the 1st and 99th percentiles
    data_capped[col] = np.clip(data_capped[col], lower_cap, upper_cap)

# Display the shape of the capped dataset
print(f"Original data shape: {data.shape}")
print(f"Capped data shape: {data_capped.shape}")

# Display the first few rows of the capped dataset
data_capped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 11
#       9     upper_cap = data_capped[col].quantile(0.99)  # 99th percentile
#      10     # Cap the values outside the 1st and 99th percentiles
# ---> 11     data_capped[col] = np.clip(data_capped[col], lower_cap, upper_cap)
#      13 # Display the shape of the capped dataset
#      14 print(f"Original data shape: {data.shape}")
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# Month vs Temperature Barplot

# %%
# Setting parameters
plt.rcParams['figure.figsize'] = [20, 10]

# Creating a bar plot
month_temp = sns.barplot(x='month', y='temp', data=data, 
                         order=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])

# Setting the title and labels
month_temp.set(title="Month Vs Temp Barplot", xlabel="Months", ylabel="Temperature")

# Display the plot
plt.show()

# %% [markdown]
# Count of days in the week

# %%
# Setting figure size without additional style or color
plt.rcParams['figure.figsize'] = [10, 10]

# Creating a count plot without specifying style or color palette
day = sns.countplot(x='day', data=data, 
                    order=['sun', 'mon', 'tue', 'wed', 'thu', 'fri', 'sat'])

# Setting the title and labels
day.set(title='Countplot for the days in the week', xlabel='Days', ylabel='Count')

# Display the plot
plt.show()

# %% [markdown]
# Scatter Plot of area  vs. temperature

# %%
# Setting figure size without additional style or color
plt.rcParams['figure.figsize'] = [8, 8]

# Creating a scatter plot without specific styles
scat = sns.scatterplot(x='temp', y='area', data=data)

# Setting the title and labels
scat.set(title="Scatter Plot of Area and Temperature", xlabel="Temperature", ylabel="Area")

# Display the plot
plt.show()

# %%
# Temporal Analysis

# Convert month and day into ordered categories
data['month'] = pd.Categorical(data['month'], categories=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'], ordered=True)
data['day'] = pd.Categorical(data['day'], categories=['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun'], ordered=True)

# Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x='month', y='area', data=data)
plt.title('Burned Area by Month')

plt.subplot(1, 2, 2)
sns.boxplot(x='day', y='area', data=data)
plt.title('Burned Area by Day of the Week')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **Burned Area by Month:**
#    - Higher fire occurrences and larger burned areas are observed in the summer and early autumn months (July to October).
#    - August shows the highest variability in burned areas, indicating potential for more severe fires.
#
# 2. **Burned Area by Day of the Week:**
#    - No significant variation in burned area by day of the week, suggesting that fire occurrences are not strongly influenced by the day of the week.
#    - Some outliers are present on almost all days, indicating occasional severe fires.

# %%
# Spatial Analysis
# Scatter plot to visualize spatial distribution
plt.figure(figsize=(8, 6))
plt.scatter(data['x'], data['y'], s=data['area'], alpha=0.5, c=data['area'],cmap='Reds')
plt.colorbar(label='Burned Area')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Spatial Distribution of Burned Area')
plt.show()

# %%
# Reducing the Right Skewness of the Area using log(n) + 1
data['u_area'] = np.log(data['area'] + 1)

# %%
# Plot distributions of numerical variables
numerical_features = ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh', 'wind', 'rain', 'area']
plt.figure(figsize=(15, 8))
for i, feature in enumerate(numerical_features):
    plt.subplot(3, 3, i+1)
    sns.histplot(data[feature], kde=True)
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **ffmc (Fine Fuel Moisture Code):**
#    - Skewed towards higher values, indicating that most fine fuels are dry, which increases fire spread potential.
#
# 2. **dmc (Duff Moisture Code):**
#    - Appears normally distributed, with most values concentrated around the middle, suggesting moderate moisture in loosely compacted organic layers.
#
# 3. **dc (Drought Code):**
#    - Positively skewed, indicating that deep organic layers are often dry, contributing to long-term fire potential.
#
# 4. **isi (Initial Spread Index):**
#    - Skewed towards lower values, with most fires having a low initial spread rate, but there are some outliers with high spread rates.
#
# 5. **temp (Temperature):**
#    - Approximately normally distributed, centered around 20°C, showing moderate to warm temperatures during fire events.
#
# 6. **rh (Relative Humidity):**
#    - Right-skewed distribution, with most values on the lower side, indicating generally dry conditions during fire occurrences.
#
# 7. **wind (Wind Speed):**
#    - Shows a bell-shaped distribution with a peak around 4 km/h, indicating mild wind speeds during fire events.
#
# 8. **rain (Rainfall):**
#    - Highly skewed with most values near zero, indicating that most fire events occurred under dry conditions with little to no rainfall.
#
# 9. **area (Burned Area):**
#    - Highly right-skewed, indicating that most fires result in small burned areas, with a few large fires significantly affecting the distribution.

# %% [markdown]
# #### **Skewed and Reduced Skewness Area Distribution**

# %%
# Setting Parameters
plt.rcParams['figure.figsize'] = [20, 10]
sns.set(style='white', font_scale=1.3)
fig, ax = plt.subplots(1, 2)

# Distribution Plots
area_dist = sns.histplot(data['area'], ax=ax[0], kde=True)
area_dist_2 = sns.histplot(data['u_area'], ax=ax[1], kde=True)

# Setting titles and labels
area_dist.set(title="Skewed Area Distribution", xlabel="Area", ylabel="Density")
area_dist_2.set(title="Reduced Skewness of Area Distribution", xlabel="U_Area", ylabel="Density")

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Correlation Heatmap**

# %%
# Correlation Heatmap 
plt.rcParams['figure.figsize'] = [12, 10]
sns.set(font_scale=1)

# Selecting only numeric columns for correlation
numeric_data = data.select_dtypes(include=[np.number])

# Plotting the heatmap
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', center=0)

# Display the plot
plt.show()

# %% [markdown]
# - **DMC and DC's Role:** The strong correlation between DMC and DC suggests that both medium and long-term drying significantly impact fire potential, which aligns with their influence on deep organic layers.
#
# - **Temperature's Influence:** The moderate correlation of temperature with DMC, DC, and ISI reinforces its role in drying and spreading fires.
#
# - **Weak Predictors for Area:** The weak correlations of all variables with `area` indicate that predicting the burned area might require more complex modeling approaches, as it is not strongly driven by any single environmental or meteorological factor.

# %% [markdown]
# #### **Fitting a normal distribution to data**

# %%
from scipy.stats import norm
import numpy as np

# Extract the 'area' data
area_data = data['area']

# Fit a normal distribution to the data
mu, std = norm.fit(area_data)

# Plot the histogram
plt.hist(area_data, bins=25, density=True, alpha=0.6)

# Plot the PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %% [markdown]
# #### **Preprocessing**

# %%
# Reducing the skewness for the final training and dropping u_area
data['area'] = np.log(data['area'] + 1)
data.drop(columns = 'u_area', inplace = True)

display(data)
# Out:
#      x  y month  day  ffmc    dmc     dc   isi  temp  rh  wind  rain      area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0  0.000000
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0  0.000000
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0  0.000000
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2  0.000000
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0  0.000000
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...       ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0  2.006871
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  4.012592
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  2.498152
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0  0.000000
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0  0.000000
#
# [517 rows x 13 columns]

# %% [markdown]
# #### **Normalization of the features**

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
minmax = MinMaxScaler()

# Apply MinMaxScaler to multiple columns at once
columns_to_scale = ['ffmc', 'dmc', 'dc', 'isi', 'rh']
data[columns_to_scale] = minmax.fit_transform(data[columns_to_scale])

# Display the scaled data
print(data.head())
# Out:
#    x  y month  day      ffmc       dmc        dc       isi  temp        rh  \
# 0  7  5   mar  fri  0.870968  0.086492  0.101325  0.090909   8.2  0.423529
# 1  7  4   oct  tue  0.927742  0.118194  0.775419  0.119430  18.0  0.211765
# 2  7  4   oct  sat  0.927742  0.146795  0.796294  0.119430  14.6  0.211765
# 3  8  6   mar  fri  0.941935  0.110958  0.081623  0.160428   8.3  0.964706
# 4  8  6   mar  sun  0.910968  0.172984  0.110590  0.171123  11.4  0.988235
#
#    wind  rain  area
# 0   6.7   0.0   0.0
# 1   0.9   0.0   0.0
# 2   1.3   0.0   0.0
# 3   4.0   0.2   0.0
# 4   1.8   0.0   0.0

# %%
data['day'].value_counts()
# Out:
# day
# sun    95
# fri    85
# sat    84
# mon    74
# tue    64
# thu    61
# wed    54
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                 x           y        ffmc         dmc          dc         isi  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807    0.928318    0.378264    0.633329    0.160814
# std      2.313778    1.229900    0.071227    0.220698    0.290918    0.081274
# min      1.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    4.000000    0.922581    0.232598    0.504046    0.115865
# 50%      4.000000    4.000000    0.940645    0.369400    0.769673    0.149733
# 75%      7.000000    5.000000    0.957419    0.486906    0.827958    0.192513
# max      9.000000    9.000000    1.000000    1.000000    1.000000    1.000000
#
#              temp          rh        wind        rain        area
# count  517.000000  517.000000  517.000000  517.000000  517.000000
# mean    18.889168    0.344567    4.017602    0.021663    1.111026
# std      5.806625    0.191970    1.791653    0.295959    1.398436
# min      2.200000    0.000000    0.400000    0.000000    0.000000
# 25%     15.500000    0.211765    2.700000    0.000000    0.000000
# 50%     19.300000    0.317647    4.000000    0.000000    0.418710
# 75%     22.800000    0.447059    4.900000    0.000000    2.024193
# max     33.300000    1.000000    9.400000    6.400000    6.995620

# %% [markdown]
# #### **Changing categorical values into numerical values**

# %%
# Ensure 'month' and 'day' columns are categorical
data['month'] = pd.Categorical(data['month'], categories=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 
                                                          'jul', 'aug', 'sep', 'oct', 'nov', 'dec'], ordered=True)
data['day'] = pd.Categorical(data['day'], categories=['sun', 'mon', 'tue', 'wed', 'thu', 'fri', 'sat'], ordered=True)

# Use cat.rename_categories to change categories
data['month'] = data['month'].cat.rename_categories({'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 
                                                     'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12})
data['day'] = data['day'].cat.rename_categories({'sun': 1, 'mon': 2, 'tue': 3, 'wed': 4, 'thu': 5, 'fri': 6, 'sat': 7})

data.head()
# Out:
#    x  y month day      ffmc       dmc        dc       isi  temp        rh  \
# 0  7  5     3   6  0.870968  0.086492  0.101325  0.090909   8.2  0.423529
# 1  7  4    10   3  0.927742  0.118194  0.775419  0.119430  18.0  0.211765
# 2  7  4    10   7  0.927742  0.146795  0.796294  0.119430  14.6  0.211765
# 3  8  6     3   6  0.941935  0.110958  0.081623  0.160428   8.3  0.964706
# 4  8  6     3   1  0.910968  0.172984  0.110590  0.171123  11.4  0.988235
#
#    wind  rain  area
# 0   6.7   0.0   0.0
# 1   0.9   0.0   0.0
# 2   1.3   0.0   0.0
# 3   4.0   0.2   0.0
# 4   1.8   0.0   0.0

# %% [markdown]
# ## **Building Model**

# %% [markdown]
# #### **Splitting the dataset into training and testing**

# %%
target = data['area']
features = data.drop(columns = 'area')

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.15, random_state = 196)

print ("Train data set size : ", X_train.shape)
print ("Test data set size : ", X_test.shape)
# Out:
# Train data set size :  (439, 12)
# Test data set size :  (78, 12)

# %%
X_train.head()
# Out:
#      x  y month day      ffmc       dmc        dc       isi  temp        rh  \
# 344  6  3     9   2  0.939355  0.444521  0.937258  0.133690  12.2  0.600000
# 6    8  6     8   2  0.949677  0.302550  0.571948  0.151515  24.1  0.141176
# 485  2  4     8   2  0.984516  0.463129  0.690043  0.379679  30.6  0.152941
# 419  2  5     8   1  0.940645  0.620951  0.709628  0.135472  24.8  0.247059
# 263  6  3     8   6  0.934194  0.482426  0.728509  0.126560  19.3  0.282353
#
#      wind  rain
# 344   4.9   0.0
# 6     3.1   0.0
# 485   3.6   0.0
# 419   4.0   0.0
# 263   3.6   0.0

# %% [markdown]
# #### **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Assuming X_train, X_test, y_train, and y_test are already defined and contain only numerical data

# Linear Regression Model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)

# Scores
print("Mean Squared Error:", mean_squared_error(y_test, predictions))
print("R-squared Score:", r2_score(y_test, predictions))
# Out:
# Mean Squared Error: 1.6721913684845613
# R-squared Score: -0.00219521462195571

# %%
# Ensure y_test and predictions are converted to the correct format if needed
y_test_array = np.array(y_test).flatten()
predictions_array = np.array(predictions).flatten()

# Create DataFrame to compare actual vs. predicted values
results_df = pd.DataFrame({'Actual': y_test_array, 'Predicted': predictions_array})

# Display the first 10 actual and predicted values
print(results_df.head(10))
# Out:
#      Actual  Predicted
# 0  0.000000   1.489796
# 1  1.862529   1.489912
# 2  3.919396   1.205563
# 3  0.000000   1.236783
# 4  2.479056   0.979878
# 5  0.741937   0.612450
# 6  0.000000   0.784848
# 7  0.000000   1.039385
# 8  4.012592   0.896674
# 9  2.409644   0.772175
